# %%
import pandas as pd



df1 = pd.read_excel("campaign_performance.xlsx")

campaign_platforms = df1.groupby('campaign_name')['platform'].nunique().reset_index()

multi_platform_campaigns = campaign_platforms[campaign_platforms['platform'] > 1]

print("Campaigns running on more than one platform:")
print(multi_platform_campaigns)
print(campaign_platforms)
# Out:
# Campaigns running on more than one platform:
# Empty DataFrame
# Columns: [campaign_name, platform]
# Index: []
#                                         campaign_name  platform
# 0   CBO - USP Masterclass Cold [ 15th Dec ] - High...         1
# 1   CBO - USP Masterclass Cold [ 15th Dec ] - More...         1
# 2   CBO - USP Masterclass Cold [ 23rd Nov ] - High...         1
# 3   CBO - USP Masterclass Cold [ 23rd Nov ] - More...         1
# 4   USP Masterclass Cold [ 14th Dec ] - Link Click Ad         1
# 5   USP Masterclass Cold [ 23rd Nov ] - More volum...         1
# 6   USP Masterclass Cold [ 31st Oct ] - Higher Int...         1
# 7   USP Masterclass Cold [ 31st Oct ] - More Volum...         1
# 8   USP Masterclass Cold [ 31st Oct ] - More volum...         1
# 9                     USP Study Abroad_Generic_240224         1
# 10                            USP_2_Lead-gen-1_220124         1
# 11                USP_2_Lead-gen-2_Top4-states_050424         1
# ...

# %%
print(df1.dtypes)
# Out:
# dates                  datetime64[ns]
# campaign_name                  object
# campaign_start_date    datetime64[ns]
# creative_name                  object
# total_spent                   float64
# impressions                     int64
# clicks                          int64
# click_through_rate            float64
# leads                         float64
# platform                       object
# adset_name                     object
# dtype: object

# %%
# import pandas as pd



# print(df['dates'].dtype)

# try:
#     df['parsed_dates'] = pd.to_datetime(df['dates'], errors='coerce', dayfirst=True)
#     print(df[['dates', 'parsed_dates']])
# except Exception as e:
#     print(f"Error parsing dates: {e}")

# %%
# import pandas as pd
# from datetime import datetime

# def find_rows_with_different_date_format(df, date_columns, date_format=("%Y-%m-%d")):
   
#     def is_valid_date(date_str, date_format):
#         try:
#             datetime.strptime(str(date_str), date_format)
#             return True
#         except ValueError:
#             return False

#     invalid_rows = []

#     for column in date_columns:
#         invalid_rows.extend(df[~df[column].apply(lambda x: is_valid_date(x, date_format))].index.tolist())

#     invalid_rows = df.loc[invalid_rows].drop_duplicates()

#     return invalid_rows

# # Example usage

# date_columns = ['dates']

# invalid_rows = find_rows_with_different_date_format(df, date_columns)
# print(invalid_rows)

# %%
df1['campaign_name'] = df1['campaign_name'].str.capitalize()

# %%
# Check the datatype of the date column
print(df1['campaign_start_date'].dtype)
# Out:
# datetime64[ns]

# %%
df1['creative_name'] = df1['creative_name'].str.capitalize()
df1.head(20)
# Out:
#         dates                        campaign_name campaign_start_date  \
# 0  2024-04-29           Usp_search_aptntska_250124                 NaT
# 1  2024-05-02  Usp_2_lead-gen-2_top4-states_050424                 NaT
# 2  2024-05-02  Usp_2_lead-gen-2_top4-states_050424                 NaT
# 3  2024-05-02  Usp_2_lead-gen-2_top4-states_050424                 NaT
# 4  2024-05-02  Usp_2_lead-gen-2_top4-states_050424                 NaT
# 5  2024-05-02  Usp_2_lead-gen-2_top4-states_050424                 NaT
# 6  2024-05-02  Usp_2_lead-gen-2_top4-states_050424                 NaT
# 7  2024-05-02      Usp study abroad_generic_240224                 NaT
# 8  2024-05-02  Usp_2_lead-gen-2_top4-states_050424                 NaT
# 9  2024-05-02              Usp_2_lead-gen-1_220124                 NaT
# 10 2024-05-02              Usp_2_lead-gen-1_220124                 NaT
# 11 2024-05-02              Usp_2_lead-gen-1_220124                 NaT
# ...

# %%
df1['total_spent'] = df1['total_spent'].round(3)
df1['click_through_rate'] = df1['click_through_rate'].round(3)

# %%
df1.head(20)
# Out:
#         dates                        campaign_name campaign_start_date  \
# 0  2024-04-29           Usp_search_aptntska_250124                 NaT
# 1  2024-05-02  Usp_2_lead-gen-2_top4-states_050424                 NaT
# 2  2024-05-02  Usp_2_lead-gen-2_top4-states_050424                 NaT
# 3  2024-05-02  Usp_2_lead-gen-2_top4-states_050424                 NaT
# 4  2024-05-02  Usp_2_lead-gen-2_top4-states_050424                 NaT
# 5  2024-05-02  Usp_2_lead-gen-2_top4-states_050424                 NaT
# 6  2024-05-02  Usp_2_lead-gen-2_top4-states_050424                 NaT
# 7  2024-05-02      Usp study abroad_generic_240224                 NaT
# 8  2024-05-02  Usp_2_lead-gen-2_top4-states_050424                 NaT
# 9  2024-05-02              Usp_2_lead-gen-1_220124                 NaT
# 10 2024-05-02              Usp_2_lead-gen-1_220124                 NaT
# 11 2024-05-02              Usp_2_lead-gen-1_220124                 NaT
# ...

# %%
filtered_df = df1[df1['campaign_start_date'].notna()]
filtered_df.head(20)
# Out:
#          dates                   campaign_name campaign_start_date  \
# 561 2023-11-17  Us_pathway_2_lead_gen_2_091123          2023-11-09
# 575 2024-03-21  Us_pathway_2_lead_gen_1_091123          2023-11-09
# 629 2024-03-22  Us_pathway_2_lead_gen_3_241123          2023-11-24
# 655 2024-03-22  Us_pathway_2_lead_gen_1_091123          2023-11-09
# 659 2024-03-28  Us_pathway_2_lead_gen_1_091123          2023-11-09
# 669 2024-03-22  Us_pathway_2_lead_gen_1_091123          2023-11-09
# 679 2024-03-27  Us_pathway_2_lead_gen_3_241123          2023-11-24
# 682 2024-04-03  Us_pathway_2_lead_gen_4_220324          2024-03-22
# 716 2024-03-22  Us_pathway_2_lead_gen_4_220324          2024-03-22
# 717 2024-04-16  Us_pathway_2_lead_gen_1_091123          2023-11-09
# 741 2023-12-02  Us_pathway_2_lead_gen_2_091123          2023-11-09
# 749 2024-04-15  Us_pathway_2_lead_gen_1_091123          2023-11-09
# 764 2024-04-16  Us_pathway_2_lead_gen_1_091123          2023-11-09
# ...

# %%
df1['adset_name'] = df1['adset_name'].str.upper()
df1.head(20)
# Out:
#         dates                        campaign_name campaign_start_date  \
# 0  2024-04-29           Usp_search_aptntska_250124                 NaT
# 1  2024-05-02  Usp_2_lead-gen-2_top4-states_050424                 NaT
# 2  2024-05-02  Usp_2_lead-gen-2_top4-states_050424                 NaT
# 3  2024-05-02  Usp_2_lead-gen-2_top4-states_050424                 NaT
# 4  2024-05-02  Usp_2_lead-gen-2_top4-states_050424                 NaT
# 5  2024-05-02  Usp_2_lead-gen-2_top4-states_050424                 NaT
# 6  2024-05-02  Usp_2_lead-gen-2_top4-states_050424                 NaT
# 7  2024-05-02      Usp study abroad_generic_240224                 NaT
# 8  2024-05-02  Usp_2_lead-gen-2_top4-states_050424                 NaT
# 9  2024-05-02              Usp_2_lead-gen-1_220124                 NaT
# 10 2024-05-02              Usp_2_lead-gen-1_220124                 NaT
# 11 2024-05-02              Usp_2_lead-gen-1_220124                 NaT
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df = df1

# Select numerical columns for plotting
numerical_columns = ['total_spent', 'impressions', 'clicks', 'click_through_rate', 'leads']



# Plot box plots
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[numerical_columns])
plt.title('Box Plot of Numerical Variables')
plt.xlabel('Variables')
plt.ylabel('Values')
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd

# Example dataframe
# data = {
#     'dates': ['2024-04-29', '2024-05-02', pd.NaT],
#     'campaign_name': ['USP_Search_APTNTSKA_250124', 'USP_2_Lead-gen-2_Top4-states_050424', 'USP_2_Lead-gen-2_Top4-states_050424'],
#     'campaign_start_date': [pd.Timestamp('2024-04-29'), pd.Timestamp('2024-05-02'), pd.NaT],
#     'total_spent': [6766.15, 946.38, 170.4],
#     'impressions': [1250, 3154, 2695],
#     'clicks': [220, 9, 8],
#     'click_through_rate': [17.60, 0.28535193, 0.29684601],
#     'leads': [25, 1, 0],
#     'platform': ['Google', 'Facebook', 'Facebook'],
#     'adset_name': ['GMAT/GRE', 'USP-2_KA_TN_050424', 'USP-2_KA_TN_050424']
# }

# df = pd.DataFrame(data)

# Select numerical columns for outlier calculation
numerical_columns = ['total_spent', 'impressions', 'clicks', 'click_through_rate', 'leads']

# Dictionary to store count of outliers for each column
outliers_count = {}

# Calculate outliers using IQR method for each numerical column
for col in numerical_columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    outliers_count[col] = len(outliers)

# Print count of outliers for each column
for col, count in outliers_count.items():
    print(f"Number of outliers in '{col}': {count}")
# Out:
# Number of outliers in 'total_spent': 3936
# Number of outliers in 'impressions': 4636
# Number of outliers in 'clicks': 4424
# Number of outliers in 'click_through_rate': 3771
# Number of outliers in 'leads': 3242

# %%
import pandas as pd
import numpy as np

# Example dataframe


# Select numerical columns for outlier calculation
numerical_columns = ['total_spent', 'impressions', 'clicks', 'click_through_rate', 'leads']

# Dictionary to store count of outliers for each column
outliers_count = {}

# Calculate outliers using Z-score method for each numerical column
for col in numerical_columns:
    # Calculate Z-score for each value in the column
    z_scores = np.abs((df[col] - df[col].mean()) / df[col].std())
    
    # Define threshold for outliers (e.g., Z-score > 3)
    threshold = 3
    
    # Count outliers
    outliers = df[z_scores > threshold]
    outliers_count[col] = len(outliers)

# Print count of outliers for each column
for col, count in outliers_count.items():
    print(f"Number of outliers in '{col}': {count}")
# Out:
# Number of outliers in 'total_spent': 595
# Number of outliers in 'impressions': 462
# Number of outliers in 'clicks': 340
# Number of outliers in 'click_through_rate': 284
# Number of outliers in 'leads': 521

# %%
from scipy import stats
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

numerical_columns = ['total_spent', 'impressions', 'clicks', 'click_through_rate', 'leads']


for col in numerical_columns:
    stat, p = stats.shapiro(df[col])
    print(f"Variable: {col}, Shapiro-Wilk test statistic: {stat:.4f}, p-value: {p:.4f}")
    
    # Visualize distribution
    plt.figure(figsize=(8, 4))
    plt.hist(df[col], bins=30, edgecolor='black')
    plt.title(f'Histogram of {col}')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.show()
# Out:
# Variable: total_spent, Shapiro-Wilk test statistic: 0.4023, p-value: 0.0000
# C:\Users\sudhe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\scipy\stats\_axis_nan_policy.py:573: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 28534.
#   res = hypotest_fun_out(*samples, **kwds)
# Variable: impressions, Shapiro-Wilk test statistic: 0.2982, p-value: 0.0000
# Variable: clicks, Shapiro-Wilk test statistic: 0.2165, p-value: 0.0000
# Variable: click_through_rate, Shapiro-Wilk test statistic: nan, p-value: nan
# Variable: leads, Shapiro-Wilk test statistic: 0.3040, p-value: 0.0000

# %%
import pandas as pd

df=pd.read_excel("campaign_performance.xlsx") 

# Calculate percentage of null values in each column
null_percentages = df.isnull().mean() * 100

print("Percentage of null values in each field:")
print(null_percentages)
df.isnull().sum()
# Out:
# Percentage of null values in each field:
# dates                   0.000000
# campaign_name           0.000000
# campaign_start_date    85.116002
# creative_name           0.000000
# total_spent             0.000000
# impressions             0.000000
# clicks                  0.000000
# click_through_rate      0.129670
# leads                   0.000000
# platform                0.000000
# adset_name             14.883998
# dtype: float64
# dates                      0
# campaign_name              0
# campaign_start_date    24287
# creative_name              0
# total_spent                0
# impressions                0
# clicks                     0
# click_through_rate        37
# leads                      0
# platform                   0
# adset_name              4247
# dtype: int64

# %%
import pandas as pd
import numpy as np
from scipy import stats

def process_column(file_name, column_name):
    if file_name.endswith('.csv'):
        df = pd.read_csv(file_name)
    elif file_name.endswith('.xlsx'):
        df = pd.read_excel(file_name)
    else:
        raise ValueError("File format not supported. Please provide a CSV or Excel file.")

    if column_name not in df.columns:
        raise ValueError(f"Column '{column_name}' not found in the dataframe.")
    
    null_count = df[column_name].isnull().sum()
    if null_count > 0:
        print(f"Column '{column_name}' has {null_count} null values.")
        action = input("Would you like to remove null values (remove) or replace with mean, median, or mode? (mean/median/mode): ").strip().lower()
        if action == 'remove':
            df = df.dropna(subset=[column_name])
        elif action == 'mean':
            df[column_name].fillna(df[column_name].mean(), inplace=True)
        elif action == 'median':
            df[column_name].fillna(df[column_name].median(), inplace=True)
        elif action == 'mode':
            df[column_name].fillna(df[column_name].mode()[0], inplace=True)
        else:
            print("Invalid action. No changes made to null values.")
    
    Q1 = df[column_name].quantile(0.25)
    Q3 = df[column_name].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound_iqr = Q1 - 1.5 * IQR
    upper_bound_iqr = Q3 + 1.5 * IQR
    outliers_iqr = df[(df[column_name] < lower_bound_iqr) | (df[column_name] > upper_bound_iqr)]
    print(f"\nIQR Method:\nNumber of outliers detected: {len(outliers_iqr)}")

    z_scores = stats.zscore(df[column_name].dropna())
    outliers_z = df[(np.abs(z_scores) > 3)]
    print(f"\nZ-score Method:\nNumber of outliers detected: {len(outliers_z)}")

    outlier_removal_method = input("\nWhich method would you like to use to remove outliers? (IQR/Z): ").strip().upper()
    if outlier_removal_method == 'IQR':
        df = df[(df[column_name] >= lower_bound_iqr) & (df[column_name] <= upper_bound_iqr)]
    elif outlier_removal_method == 'Z':
        df = df[np.abs(z_scores) <= 3]
    else:
        print("Invalid method. No changes made to outliers.")

    return df

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

def load_data(file_name):
    if file_name.endswith('.csv'):
        return pd.read_csv(file_name)
    elif file_name.endswith('.xlsx'):
        return pd.read_excel(file_name)
    else:
        raise ValueError("File format not supported. Please provide a CSV or Excel file.")

def display_statistics(df):
    print("\nData Overview:")
    print(df.describe(include='all'))
    print("\nNull Values:")
    print(df.isnull().sum())
    print("\nDuplicate Rows:")
    print(df.duplicated().sum())
    print("\nNegative Values:")
    negative_values = (df.select_dtypes(include=[np.number]) < 0).sum()
    print(negative_values[negative_values > 0])

def handle_null_values(df, column):
    action = input(f"Column '{column}' has null values. Would you like to remove (remove) or replace with mean, median, or mode? (mean/median/mode): ").strip().lower()
    if action == 'remove':
        df = df.dropna(subset=[column])
    elif action == 'mean':
        df[column].fillna(df[column].mean(), inplace=True)
    elif action == 'median':
        df[column].fillna(df[column].median(), inplace=True)
    elif action == 'mode':
        df[column].fillna(df[column].mode()[0], inplace=True)
    else:
        print("Invalid action. No changes made to null values.")
    return df

def handle_duplicates(df):
    action = input("Would you like to remove duplicate rows? (yes/no): ").strip().lower()
    if action == 'yes':
        df = df.drop_duplicates()
    return df

def handle_outliers(df, column):
    show_plots(df, column, "Before Outlier Removal")
    
    # Check for outliers using IQR
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound_iqr = Q1 - 1.5 * IQR
    upper_bound_iqr = Q3 + 1.5 * IQR
    outliers_iqr = df[(df[column] < lower_bound_iqr) | (df[column] > upper_bound_iqr)]
    print(f"\nIQR Method:\nNumber of outliers detected: {len(outliers_iqr)}")

    # Check for outliers using Z-score
    z_scores = stats.zscore(df[column].dropna())
    outliers_z = df[(np.abs(z_scores) > 3)]
    print(f"\nZ-score Method:\nNumber of outliers detected: {len(outliers_z)}")

    # Choose method to remove outliers
    outlier_removal_method = input("\nWhich method would you like to use to remove outliers? (IQR/Z): ").strip().upper()
    if outlier_removal_method == 'IQR':
        df = df[(df[column] >= lower_bound_iqr) & (df[column] <= upper_bound_iqr)]
    elif outlier_removal_method == 'Z':
        df = df[np.abs(z_scores) <= 3]
    else:
        print("Invalid method. No changes made to outliers.")
    
    show_plots(df, column, "After Outlier Removal")
    return df

def show_plots(df, column, title_suffix):
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    sns.boxplot(x=df[column])
    plt.title(f'Boxplot - {column} ({title_suffix})')

    plt.subplot(1, 2, 2)
    sns.histplot(df[column], kde=True)
    plt.title(f'Histogram - {column} ({title_suffix})')
    plt.show()

def process_data(file_name):
    df = load_data(file_name)
    display_statistics(df)
    
    columns = input("Enter the column names you want to process (comma-separated) or type 'all' for all columns: ").strip().lower()
    if columns == 'all':
        columns = df.columns
    else:
        columns = [col.strip() for col in columns.split(',')]
    
    for column in columns:
        if df[column].isnull().sum() > 0:
            df = handle_null_values(df, column)
        
        if df.duplicated().sum() > 0:
            df = handle_duplicates(df)
        
        if pd.api.types.is_numeric_dtype(df[column]) and len(df[column].unique()) > 2:  # Skip categorical data
            df = handle_outliers(df, column)
    
    return df

# Example usage:
# cleaned_df = process_data('data.csv')
df=process_data("campaign_performance.xlsx")
# Out:
# Data Overview:
#                                 dates                    campaign_name  \
# count                           28534                            28534
# unique                            NaN                               41
# top                               NaN  USP Study Abroad_Generic_240224
# freq                              NaN                             4583
# mean    2024-02-05 04:47:15.186093824                              NaN
# min               2023-11-01 00:00:00                              NaN
# 25%               2023-12-25 00:00:00                              NaN
# 50%               2024-02-06 00:00:00                              NaN
# 75%               2024-03-19 00:00:00                              NaN
# max               2024-05-04 00:00:00                              NaN
# std                               NaN                              NaN
#
#                   campaign_start_date  \
# count                            4247
# ...

# %%
df = pd.read_excel('campaign_performance.xlsx')

null_counts = df.isnull().sum()
null_percentages = (null_counts / len(df)) * 100

print(null_counts,"\n")
print(null_percentages)
# Out:
# dates                      0
# campaign_name              0
# campaign_start_date    24287
# creative_name              0
# total_spent                0
# impressions                0
# clicks                     0
# click_through_rate        37
# leads                      0
# platform                   0
# adset_name              4247
# dtype: int64
#
# dates                   0.000000
# campaign_name           0.000000
# campaign_start_date    85.116002
# creative_name           0.000000
# total_spent             0.000000
# impressions             0.000000
# clicks                  0.000000
# click_through_rate      0.129670
# leads                   0.000000
# platform                0.000000
# adset_name             14.883998
# dtype: float64

# %%
import pandas as pd
from datetime import datetime

def extract_date_from_campaign(campaign_name):
    date_str = campaign_name[-6:]
    try:
        return datetime.strptime(date_str, '%d%m%y').strftime('%d-%m-%Y')
    except ValueError:
        return None

df['campaign_start_date'] = df.apply(
    lambda row: extract_date_from_campaign(row['campaign_name']) if pd.isnull(row['campaign_start_date']) else row['campaign_start_date'],
    axis=1
)

df['campaign_start_date'] = pd.to_datetime(df['campaign_start_date'], format='%d-%m-%Y', errors='coerce')

print(df)
# Out:
#            dates                        campaign_name campaign_start_date  \
# 0     2024-04-29           USP_Search_APTNTSKA_250124          2024-01-25
# 1     2024-05-02  USP_2_Lead-gen-2_Top4-states_050424          2024-04-05
# 2     2024-05-02  USP_2_Lead-gen-2_Top4-states_050424          2024-04-05
# 3     2024-05-02  USP_2_Lead-gen-2_Top4-states_050424          2024-04-05
# 4     2024-05-02  USP_2_Lead-gen-2_Top4-states_050424          2024-04-05
# ...          ...                                  ...                 ...
# 28529 2024-03-12        USP_MS + Coop Campaign_240224          2024-02-24
# 28530 2024-03-12        USP_MS + Coop Campaign_240224          2024-02-24
# 28531 2024-03-12      USP Study Abroad_Generic_240224          2024-02-24
# 28532 2024-03-12      USP Study Abroad_Generic_240224          2024-02-24
# 28533 2024-03-12      USP Study Abroad_Generic_240224          2024-02-24
#
#                            creative_name  total_spent  impressions  clicks  \
# ...

# %%
import pandas as pd

df['clicks'] = pd.to_numeric(df['clicks'], errors='coerce')
df['impressions'] = pd.to_numeric(df['impressions'], errors='coerce')

df['click_through_rate'] = df.apply(
    lambda row: (row['clicks'] / row['impressions'] * 100) if pd.isnull(row['click_through_rate']) and row['impressions'] > 0 else row['click_through_rate'],
    axis=1
)

df['click_through_rate'] = pd.to_numeric(df['click_through_rate'], errors='coerce')

print(df)
# Out:
#            dates                        campaign_name campaign_start_date  \
# 0     2024-04-29           USP_Search_APTNTSKA_250124          2024-01-25
# 1     2024-05-02  USP_2_Lead-gen-2_Top4-states_050424          2024-04-05
# 2     2024-05-02  USP_2_Lead-gen-2_Top4-states_050424          2024-04-05
# 3     2024-05-02  USP_2_Lead-gen-2_Top4-states_050424          2024-04-05
# 4     2024-05-02  USP_2_Lead-gen-2_Top4-states_050424          2024-04-05
# ...          ...                                  ...                 ...
# 28529 2024-03-12        USP_MS + Coop Campaign_240224          2024-02-24
# 28530 2024-03-12        USP_MS + Coop Campaign_240224          2024-02-24
# 28531 2024-03-12      USP Study Abroad_Generic_240224          2024-02-24
# 28532 2024-03-12      USP Study Abroad_Generic_240224          2024-02-24
# 28533 2024-03-12      USP Study Abroad_Generic_240224          2024-02-24
#
#                            creative_name  total_spent  impressions  clicks  \
# ...

# %%
df['adset_name'] = df['adset_name'].astype(str)

most_frequent_adsets = df.groupby('campaign_name')['adset_name'].agg(lambda x: x.mode()[0] if not x.mode().empty else None)

df['adset_name'] = df.apply(lambda row: most_frequent_adsets[row['campaign_name']] if pd.isnull(row['adset_name']) else row['adset_name'], axis=1)

print(df)
# Out:
#            dates                        campaign_name campaign_start_date  \
# 0     2024-04-29           USP_Search_APTNTSKA_250124          2024-01-25
# 1     2024-05-02  USP_2_Lead-gen-2_Top4-states_050424          2024-04-05
# 2     2024-05-02  USP_2_Lead-gen-2_Top4-states_050424          2024-04-05
# 3     2024-05-02  USP_2_Lead-gen-2_Top4-states_050424          2024-04-05
# 4     2024-05-02  USP_2_Lead-gen-2_Top4-states_050424          2024-04-05
# ...          ...                                  ...                 ...
# 28529 2024-03-12        USP_MS + Coop Campaign_240224          2024-02-24
# 28530 2024-03-12        USP_MS + Coop Campaign_240224          2024-02-24
# 28531 2024-03-12      USP Study Abroad_Generic_240224          2024-02-24
# 28532 2024-03-12      USP Study Abroad_Generic_240224          2024-02-24
# 28533 2024-03-12      USP Study Abroad_Generic_240224          2024-02-24
#
#                            creative_name  total_spent  impressions  clicks  \
# ...

# %%
df=df.dropna(subset="click_through_rate")

# %%
null_counts = df.isnull().sum()
null_percentages = (null_counts / len(df)) * 100

print(null_counts,"\n")
print(null_percentages)
# Out:
# dates                     0
# campaign_name             0
# campaign_start_date    9103
# creative_name             0
# total_spent               0
# impressions               0
# clicks                    0
# click_through_rate        0
# leads                     0
# platform                  0
# adset_name                0
# dtype: int64
#
# dates                   0.000000
# campaign_name           0.000000
# campaign_start_date    31.940351
# creative_name           0.000000
# total_spent             0.000000
# impressions             0.000000
# clicks                  0.000000
# click_through_rate      0.000000
# leads                   0.000000
# platform                0.000000
# adset_name              0.000000
# dtype: float64

# %%
import pandas as pd

# Print rows where campaign_start_date is null
print("Rows where campaign_start_date is null:")
print(df[df['campaign_start_date'].isnull()])

# Print campaign_names where campaign_start_date is null
print("\nCampaign names where campaign_start_date is null:")
print(df.loc[df['campaign_start_date'].isnull(), 'campaign_name'])
# Out:
# Rows where campaign_start_date is null:
#            dates                                      campaign_name  \
# 888   2023-12-29  CBO - USP Masterclass Cold [ 23rd Nov ] - High...
# 889   2023-12-29  USP Masterclass Cold [ 31st Oct ] - Higher Int...
# 891   2023-12-29  USP Masterclass Cold [ 31st Oct ] - Higher Int...
# 892   2023-12-29  USP Masterclass Cold [ 31st Oct ] - Higher Int...
# 895   2023-12-29  USP Masterclass Cold [ 31st Oct ] - Higher Int...
# ...          ...                                                ...
# 28429 2024-01-01      USP_Video_More_Volume_No Logic_India_New Link
# 28449 2023-12-03  CBO - USP Masterclass Cold [ 23rd Nov ] - More...
# 28490 2023-11-28  CBO - USP Masterclass Cold [ 23rd Nov ] - High...
# 28499 2023-12-28      USP_Video_More_Volume_No Logic_India_New Link
# 28500 2023-12-20  USP Masterclass Cold [ 31st Oct ] - Higher Int...
#
#       campaign_start_date                                      creative_name  \
# ...

# %%
import pandas as pd

# Identify numerical columns
numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns

# Round numerical columns to three decimal places
df[numerical_cols] = df[numerical_cols].round(3)

# Display the DataFrame to check results
print(df)
# Out:
#            dates                        campaign_name campaign_start_date  \
# 0     2024-04-29           USP_Search_APTNTSKA_250124          2024-01-25
# 1     2024-05-02  USP_2_Lead-gen-2_Top4-states_050424          2024-04-05
# 2     2024-05-02  USP_2_Lead-gen-2_Top4-states_050424          2024-04-05
# 3     2024-05-02  USP_2_Lead-gen-2_Top4-states_050424          2024-04-05
# 4     2024-05-02  USP_2_Lead-gen-2_Top4-states_050424          2024-04-05
# ...          ...                                  ...                 ...
# 28529 2024-03-12        USP_MS + Coop Campaign_240224          2024-02-24
# 28530 2024-03-12        USP_MS + Coop Campaign_240224          2024-02-24
# 28531 2024-03-12      USP Study Abroad_Generic_240224          2024-02-24
# 28532 2024-03-12      USP Study Abroad_Generic_240224          2024-02-24
# 28533 2024-03-12      USP Study Abroad_Generic_240224          2024-02-24
#
#                            creative_name  total_spent  impressions  clicks  \
# ...

# %%
df['cost_per_click'] = df['total_spent'] / df['clicks']
df['cost_per_lead'] = df['total_spent'] / df['leads']
df['conversion_rate'] = df['leads'] / df['clicks']

# %%
df.to_excel("cl_campaign1.xlsx")

# %%
plt.figure(figsize=(16, 12))
for i, col in enumerate(['impressions', 'clicks', 'click_through_rate', 'leads', 'cost_per_click', 'cost_per_lead', 'conversion_rate'], 1):
    plt.subplot(3, 3, i)
    sns.scatterplot(x=df['total_spent'], y=df[col])
    plt.title(f'Total Spent vs {col}')
    plt.xlabel('Total Spent')
    plt.ylabel(col)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the dataset
# df = pd.read_excel('your_file.xlsx') # Uncomment and adjust if needed

# Distribution of numerical variables

numerical_cols = ['total_spent', 'impressions', 'clicks', 'click_through_rate', 'leads', 'cost_per_click', 'cost_per_lead', 'conversion_rate']

plt.figure(figsize=(18, 15))

# Histogram and KDE
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(4, 2, i)
    sns.histplot(df[col].dropna(), kde=True, bins=30)
    # plt.title(f'Histogram and KDE of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

# Box Plot
# plt.figure(figsize=(18, 12))
# for i, col in enumerate(numerical_cols, 1):
#     plt.subplot(4, 2, i)
#     sns.boxplot(x=df[col].dropna())
#     plt.title(f'Box Plot of {col}')
#     plt.xlabel(col)

# Violin Plot
plt.figure(figsize=(18, 12))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(4, 2, i)
    sns.violinplot(x=df[col].dropna())
    plt.title(f'Violin Plot of {col}')
    plt.xlabel(col)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# 1. Platform Performance Comparison
platform_metrics = df.groupby('platform').agg({
    'total_spent': 'sum',
    'impressions': 'sum',
    'clicks': 'sum',
    'leads': 'sum'
}).reset_index()

platform_metrics['cpc'] = platform_metrics['total_spent'] / platform_metrics['clicks']
platform_metrics['cpl'] = platform_metrics['total_spent'] / platform_metrics['leads']
platform_metrics['ctr'] = platform_metrics['clicks'] / platform_metrics['impressions']

fig = make_subplots(rows=2, cols=2, subplot_titles=('Total Spent', 'CTR', 'CPC', 'CPL'))

fig.add_trace(go.Bar(x=platform_metrics['platform'], y=platform_metrics['total_spent'], name='Total Spent'), row=1, col=1)
fig.add_trace(go.Bar(x=platform_metrics['platform'], y=platform_metrics['ctr'], name='CTR'), row=1, col=2)
fig.add_trace(go.Bar(x=platform_metrics['platform'], y=platform_metrics['cpc'], name='CPC'), row=2, col=1)
fig.add_trace(go.Bar(x=platform_metrics['platform'], y=platform_metrics['cpl'], name='CPL'), row=2, col=2)

fig.update_layout(height=800, width=1000, title_text="Platform Performance Comparison")
fig.write_html("platform_performance_comparison.html")
fig.show()

print("1. Platform Performance Comparison created.")

# 2. Correlation Heatmap
correlation_matrix = df[['total_spent', 'impressions', 'clicks', 'click_through_rate', 'leads']].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()

print("2. Correlation Heatmap created.")

# 3. Campaign Performance Bubble Chart
campaign_performance = df.groupby('campaign_name').agg({
    'total_spent': 'sum',
    'impressions': 'sum',
    'clicks': 'sum',
    'leads': 'sum'
}).reset_index()

campaign_performance['ctr'] = campaign_performance['clicks'] / campaign_performance['impressions']
campaign_performance['conversion_rate'] = campaign_performance['leads'] / campaign_performance['clicks']

fig = px.scatter(campaign_performance, x='ctr', y='conversion_rate', size='total_spent', 
                 color='impressions', hover_name='campaign_name',
                 title='Campaign Performance')

fig.update_layout(height=600, width=1000)
fig.write_html("campaign_performance_bubble_chart.html")
fig.show()

print("3. Campaign Performance Bubble Chart created.")

# 4. Daily Trend Analysis
daily_metrics = df.groupby('dates').agg({
    'total_spent': 'sum',
    'impressions': 'sum',
    'clicks': 'sum',
    'leads': 'sum'
}).reset_index()

daily_metrics['ctr'] = daily_metrics['clicks'] / daily_metrics['impressions']
daily_metrics['conversion_rate'] = daily_metrics['leads'] / daily_metrics['clicks']

fig = make_subplots(rows=3, cols=1, shared_xaxes=True, vertical_spacing=0.05,
                    subplot_titles=('Total Spent', 'CTR', 'Conversion Rate'))

fig.add_trace(go.Scatter(x=daily_metrics['dates'], y=daily_metrics['total_spent'], mode='lines', name='Total Spent'), row=1, col=1)
fig.add_trace(go.Scatter(x=daily_metrics['dates'], y=daily_metrics['ctr'], mode='lines', name='CTR'), row=2, col=1)
fig.add_trace(go.Scatter(x=daily_metrics['dates'], y=daily_metrics['conversion_rate'], mode='lines', name='Conversion Rate'), row=3, col=1)

fig.update_layout(height=900, width=1000, title_text="Daily Trend Analysis")
fig.write_html("daily_trend_analysis.html")
fig.show()

print("4. Daily Trend Analysis created.")
# Out:
# 1. Platform Performance Comparison created.
# 2. Correlation Heatmap created.
# 3. Campaign Performance Bubble Chart created.
# 4. Daily Trend Analysis created.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df[['total_spent', 'impressions', 'clicks', 'click_through_rate', 'leads']].corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()



# Top 10 campaigns by total spent
top_campaigns = df.groupby('campaign_name')['total_spent'].sum().nlargest(10)
plt.figure(figsize=(12, 6))
top_campaigns.plot(kind='bar')
plt.title('Top 10 Campaigns by Total Spent')
plt.xlabel('Campaign Name')
plt.ylabel('Total Spent')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Performance by platform
platform_performance = df.groupby('platform').agg({
    'total_spent': 'sum',
    'impressions': 'sum',
    'clicks': 'sum',
    'leads': 'sum'
}).reset_index()
platform_performance['ctr'] = platform_performance['clicks'] / platform_performance['impressions']
platform_performance['cpl'] = platform_performance['total_spent'] / platform_performance['leads']
print("\nPerformance by Platform:")
print(platform_performance)
# Out:
# Performance by Platform:
#    platform  total_spent  impressions  clicks     leads       ctr          cpl
# 0  Facebook   8970978.34     43202021  270165  27536.00  0.006254   325.790904
# 1    Google   1648768.35      8094970  165603   3630.34  0.020458   454.163618
# 2  LinkedIn   5205343.00     16642988   99833   2868.00  0.005999  1814.973152

# %%
df['dates'] = pd.to_datetime(df['dates'])

daily_performance = df.groupby('dates').agg({
    'total_spent': 'sum',
    'impressions': 'sum',
    'clicks': 'sum',
    'leads': 'sum'
}).reset_index()

plt.figure(figsize=(12, 8))
plt.plot(daily_performance['dates'], daily_performance['total_spent'], label='Total Spent')
plt.plot(daily_performance['dates'], daily_performance['impressions'], label='Impressions')
plt.plot(daily_performance['dates'], daily_performance['leads'], label='Leads')
plt.title('Performance Metrics Over Time')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the dataset
# df = pd.read_excel('your_file.xlsx') # Uncomment and adjust if needed

# Get top 7 campaigns by total spending
top_campaigns = df.groupby('campaign_name').agg({
    'total_spent': 'sum',
    'impressions': 'sum',
    'clicks': 'sum',
    'leads': 'sum',
    'click_through_rate': 'mean',
    'cost_per_click': 'mean',
    'cost_per_lead': 'mean',
    'conversion_rate': 'mean'
}).reset_index()

top_campaigns = top_campaigns.sort_values(by='total_spent', ascending=False).head(7)
print(top_campaigns)
plt.figure(figsize=(16, 12))

# Plot Total Spent for Top 7 Campaigns
plt.subplot(2, 2, 1)
sns.barplot(x='total_spent', y='campaign_name', data=top_campaigns, palette='viridis')
plt.title('Total Spent by Campaign')
plt.xlabel('Total Spent')
plt.ylabel('Campaign Name')

# Plot Impressions for Top 7 Campaigns
plt.subplot(2, 2, 2)
sns.barplot(x='impressions', y='campaign_name', data=top_campaigns, palette='viridis')
plt.title('Impressions by Campaign')
plt.xlabel('Impressions')
plt.ylabel('Campaign Name')

# Plot Clicks for Top 7 Campaigns
plt.subplot(2, 2, 3)
sns.barplot(x='clicks', y='campaign_name', data=top_campaigns, palette='viridis')
plt.title('Clicks by Campaign')
plt.xlabel('Clicks')
plt.ylabel('Campaign Name')

# Plot Leads for Top 7 Campaigns
plt.subplot(2, 2, 4)
sns.barplot(x='leads', y='campaign_name', data=top_campaigns, palette='viridis')
plt.title('Leads by Campaign')
plt.xlabel('Leads')
plt.ylabel('Campaign Name')

plt.tight_layout()
plt.show()
# Out:
#                                   campaign_name  total_spent  impressions  \
# 9               USP Study Abroad_Generic_240224   2126684.24      9265548
# 35               US_Pathway_2_Lead_gen_1_091123   1884063.88      5751255
# 37               US_Pathway_2_Lead_gen_3_241123   1749087.89      6317435
# 13                USP_MS + Coop Campaign_240224   1501040.54      4506382
# 36               US_Pathway_2_Lead_gen_2_091123   1469168.59      4225764
# 14  USP_Marketing+MBA_New Leads Campaign_240224   1125425.52      8106285
# 24                   USP_Search_APTNTSKA_250124    789571.12       178830
#
#     clicks   leads  click_through_rate  cost_per_click  cost_per_lead  \
# 9    48531  4630.0            1.593034             inf            inf
# 35   34923  1232.0            0.008087             inf            inf
# 37   36201   874.0            0.006374             inf            inf
# 13   27762  4446.0            1.783920             inf            inf
# ...
