# %% [markdown]
# <a href="https://colab.research.google.com/github/Sudheerbmb/IT/blob/main/2nd_july(Seaborn).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install seaborn
import seaborn as sns

# %%
df=sns.load_dataset('tips')
print(df)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.lineplot(x='total_bill',y='tip',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
data={"Players":["surya","rohit","virat","pant"],"Runs":[100,200,300,400]}
sns.lineplot(x="Players",y="Runs",data=data)
# Out:
# <Axes: xlabel='Players', ylabel='Runs'>

# %%
x=[1,2,3,4,5]
y=["A","B","C","D","E"]
sns.lineplot(x=y,y=x)
# Out:
# <Axes: >

# %%
data=sns.load_dataset('tips')
print(data)
sns.lineplot(x='sex',y='tip',data=data)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# <Axes: xlabel='sex', ylabel='tip'>

# %%
df=sns.load_dataset('tips')


print(data)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data=sns.load_dataset('flights')
print(data)
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.lineplot(x="year",y="passengers",data=data,hue="month")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
data=sns.load_dataset("penguins")
print(data)
sns.histplot(data=data,x="flipper_length_mm",hue="species",multiple="stack")
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.histplot(data=data, x="flipper_length_mm",color="green", bins=30,binwidth=3, kde=True)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=data
             , x="flipper_length_mm", hue="species", multiple="layer")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data, x="flipper_length_mm", hue="species", element="step")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data, x="flipper_length_mm", hue="species", element="poly")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
tips = sns.load_dataset("tips")
sns.histplot(data=tips, x="size", stat="percent")
# Out:
# <Axes: xlabel='size', ylabel='Percent'>

# %%
tips = sns.load_dataset("tips")
# sns.histplot(data=tips, x="size", stat="count")
# print(sns.histplot(data=tips, x="size", stat="frequency"))
# print(sns.histplot(data=tips, x="size", stat="probability"))
print(sns.histplot(data=tips, x="size", stat="density"))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
sns.histplot(data=tips, x="day", hue="sex", multiple="dodge", shrink=.8)
# Out:
# <Axes: xlabel='day', ylabel='Count'>

# %%
sns.barplot(x="species",y="bill_depth_mm",data=data)
# Out:
# <Axes: xlabel='species', ylabel='bill_depth_mm'>

# %%
sns.barplot(x="island",y="body_mass_g",data=data,hue="sex")
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %%
data=sns.load_dataset("flights")
flights_wide= data.pivot(index="year",columns="month",values="passengers")
print(flights_wide)
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
sns.barplot(data=flights_wide)
# Out:
# <Axes: xlabel='month'>

# %%
print(flights_wide)
sns.barplot(flights_wide["Jun"])

# sns.barplot
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432
# <Axes: xlabel='year', ylabel='Jun'>

# %%
df=sns.load_dataset("tips")
df.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['total_bill'].plot(kind='hist', bins=20, title='total_bill')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['tip'].plot(kind='hist', bins=20, title='tip')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['size'].plot(kind='hist', bins=20, title='size')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True,linewidth=2,cmap="crest")
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df,x="total_bill",y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df,x="total_bill",y="tip",hue="time",style="time",size="size",palette="deep",alpha=0.8)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
data.head()
sns.kdeplot(x="year",data=data)
# Out:
# <Axes: xlabel='year', ylabel='Density'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data=sns.load_dataset("tips")
sns.set_style("darkgrid")
sns.kdeplot(x="total_bill",data=data,hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(
    data=data,
    x="total_bill",
    hue="time",
    fill =True,
    palette="flare",
    alpha=0.5,
    cut=0
)
plt.title("Density Plot of Total Bill by Time of Day")
plt.show()

# %%
sns.kdeplot(data=data,x="tip")
sns.rugplot(data=data,x="tip")
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.scatterplot(data=data,x="total_bill",y="tip")
sns.rugplot(data=data,x="total_bill",y="tip",height=0.07,alpha=1)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
print(data)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.boxplot(x="day",y="total_bill",data=data)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day",y="total_bill",data=data)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day",y="total_bill",data=data,hue="time",order=["Fri"],split=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.pairplot(data)

# %%
sns.pairplot(data,hue="sex")

# %%
sns.pairplot(data,hue="sex")

# %%
sns.pairplot(data,hue="sex",x_vars=["total_bill","tip"],y_vars=["total_bill","tip"])
