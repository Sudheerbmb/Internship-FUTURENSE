# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Loan 2.csv")
print(df.head())
print(df.info())
# Out:
#   Customer ID               Name Gender  Age  Income (USD) Income Stability  \
# 0     C-36995   Frederica Shealy      F   56       1933.05              Low
# 1     C-33999  America Calderone      M   32       4952.91              Low
# 2      C-3770      Rosetta Verne      F   65        988.19             High
# 3     C-26480         Zoe Chitty      F   65           NaN             High
# 4     C-23459       Afton Venema      F   31       2614.77              Low
#
#   Profession     Type of Employment    Location  Loan Amount Request (USD)  \
# 0    Working            Sales staff  Semi-Urban                   72809.58
# 1    Working                    NaN  Semi-Urban                   46837.47
# 2  Pensioner                    NaN  Semi-Urban                   45593.04
# 3  Pensioner                    NaN       Rural                   80057.92
# 4    Working  High skill tech staff  Semi-Urban                  113858.89
#
# ...

# %%
print(df.isnull().sum())
# Out:
# Customer ID                       0
# Name                              0
# Gender                           53
# Age                               0
# Income (USD)                   4576
# Income Stability               1683
# Profession                        0
# Type of Employment             7270
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)     172
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                     2493
# Credit Score                   1703
# No. of Defaults                   0
# Has Active Credit Card         1566
# Property ID                       0
# Property Age                   4850
# Property Type                     0
# Property Location               356
# Co-Applicant                      0
# Property Price                    0
# Loan Sanction Amount (USD)      340
# dtype: int64

# %%
round((df.isnull().sum()/df.shape[0])*100,2)
# Out:
# Customer ID                     0.00
# Name                            0.00
# Gender                          0.18
# Age                             0.00
# Income (USD)                   15.25
# Income Stability                5.61
# Profession                      0.00
# Type of Employment             24.23
# Location                        0.00
# Loan Amount Request (USD)       0.00
# Current Loan Expenses (USD)     0.57
# Expense Type 1                  0.00
# Expense Type 2                  0.00
# Dependents                      8.31
# Credit Score                    5.68
# No. of Defaults                 0.00
# Has Active Credit Card          5.22
# Property ID                     0.00
# Property Age                   16.17
# Property Type                   0.00
# Property Location               1.19
# Co-Applicant                    0.00
# Property Price                  0.00
# Loan Sanction Amount (USD)      1.13
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Customer ID                  30000 non-null  object
#  1   Name                         30000 non-null  object
#  2   Gender                       29947 non-null  object
#  3   Age                          30000 non-null  int64
#  4   Income (USD)                 25424 non-null  float64
#  5   Income Stability             28317 non-null  object
#  6   Profession                   30000 non-null  object
#  7   Type of Employment           22730 non-null  object
#  8   Location                     30000 non-null  object
#  9   Loan Amount Request (USD)    30000 non-null  float64
#  10  Current Loan Expenses (USD)  29828 non-null  float64
#  11  Expense Type 1               30000 non-null  object
#  12  Expense Type 2               30000 non-null  object
# ...

# %%
df1=df.dropna(subset=["Gender"])
df1.isnull().sum()
round((df1.isnull().sum()/df1.shape[0])*100,2)
# Out:
# Customer ID                     0.00
# Name                            0.00
# Gender                          0.00
# Age                             0.00
# Income (USD)                   15.26
# Income Stability                5.61
# Profession                      0.00
# Type of Employment             24.24
# Location                        0.00
# Loan Amount Request (USD)       0.00
# Current Loan Expenses (USD)     0.57
# Expense Type 1                  0.00
# Expense Type 2                  0.00
# Dependents                      8.31
# Credit Score                    5.67
# No. of Defaults                 0.00
# Has Active Credit Card          5.23
# Property ID                     0.00
# Property Age                   16.17
# Property Type                   0.00
# Property Location               1.19
# Co-Applicant                    0.00
# Property Price                  0.00
# Loan Sanction Amount (USD)      1.13
# dtype: float64

# %%
plt.figure(figsize=(16, 8))  

plt.subplot(1, 2, 1)
sns.histplot(df['Income (USD)'])
plt.title('Histogram of Income (USD)')
plt.xlim(0, 10000)

plt.subplot(1, 2, 2)
sns.kdeplot(df['Income (USD)'])
plt.title('Density Plot of Income (USD)')
plt.xlim(0, 10000)

plt.tight_layout()
plt.show()



numerical_features = ['Age', 'Income (USD)', 'Loan Amount Request (USD)', 'Current Loan Expenses (USD)', 'Credit Score', 'Property Age', 'Property Price', 'Loan Sanction Amount (USD)']
for feature in numerical_features:
    plt.figure(figsize=(10, 6))
    sns.histplot(df[feature], kde=True)
    plt.title(f'Distribution of {feature}')

    plt.show()


categorical_features = ['Gender', 'Income Stability', 'Profession', 'Type of Employment', 'Location', 'Expense Type 1', 'Expense Type 2', 'Property Type', 'Property Location', 'Co-Applicant']
for feature in categorical_features:
    plt.figure(figsize=(10, 6))
    sns.countplot(y=df[feature], order=df[feature].value_counts().index)
    plt.title(f'Count plot of {feature}')
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy.stats import shapiro
print("Descriptive Statistics:")
print(df['Income (USD)'].describe())

print("\nSkewness:", df['Income (USD)'].skew())
print("Kurtosis:", df['Income (USD)'].kurt())
plt.figure(figsize=(16, 8))

plt.subplot(2, 2, 1)
sns.histplot(df['Income (USD)'], kde=True)
plt.title('Histogram with KDE of Income (USD)')
plt.xlim(0, 10000)

plt.subplot(2, 2, 2)
sns.boxplot(x=df['Income (USD)'])
plt.title('Boxplot of Income (USD)')
plt.xlim(0, 10000)

plt.subplot(2, 2, 3)
stats.probplot(df['Income (USD)'], dist="norm", plot=plt)
plt.title('Q-Q Plot of Income (USD)')

plt.subplot(2, 2, 4)
sns.kdeplot(df['Income (USD)'], bw_adjust=0.5)
plt.title('Density Plot of Income (USD)')
plt.xlim(0, 10000)

plt.tight_layout()
plt.show()

stat, p = shapiro(df['Income (USD)'].dropna())
print('Shapiro-Wilk Test Statistics=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Sample looks Gaussian (fail to reject H0)')
else:
    print('Sample does not look Gaussian (reject H0)')

# Pairplot for selected fields (Example)
# sns.pairplot(df[['Income (USD)', 'Age', 'Credit Score']])
# plt.show()
# Out:
# Descriptive Statistics:
# count    2.542400e+04
# mean     2.630574e+03
# std      1.126272e+04
# min      3.777000e+02
# 25%      1.650457e+03
# 50%      2.222435e+03
# 75%      3.090593e+03
# max      1.777460e+06
# Name: Income (USD), dtype: float64
#
# Skewness: 154.0017199982858
# Kurtosis: 24259.668955784848
# Shapiro-Wilk Test Statistics=0.021, p=0.000
# Sample does not look Gaussian (reject H0)
# C:\Users\sudhe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\scipy\stats\_axis_nan_policy.py:573: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 25424.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
# import pandas as pd

Q1 = df['Income (USD)'].quantile(0.25)
Q3 = df['Income (USD)'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['Income (USD)'] < lower_bound) | (df['Income (USD)'] > upper_bound)]
outlier_count = outliers.shape[0]

print(f'Number of outliers using IQR method: {outlier_count}')
# Out:
# Number of outliers using IQR method: 1124

# %%
df1['Income (USD)'] = df1['Income (USD)'].fillna(value=df1['Income (USD)'].median())
# df1['Income (USD)']=df1["Income (USD)"].fillna(value=df1["Income (USD)"].median())
df1.isnull().sum()
# Out:
# C:\Users\sudhe\AppData\Local\Temp\ipykernel_19552\3765635528.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Income (USD)'] = df1['Income (USD)'].fillna(value=df1['Income (USD)'].median())
# Customer ID                       0
# Name                              0
# Gender                            0
# Age                               0
# Income (USD)                      0
# Income Stability               1679
# Profession                        0
# Type of Employment             7258
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)     172
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                     2488
# ...

# %%
round((df1.isnull().sum()/df1.shape[0])*100,2)
# Out:
# Customer ID                     0.00
# Name                            0.00
# Gender                          0.00
# Age                             0.00
# Income (USD)                    0.00
# Income Stability                5.61
# Profession                      0.00
# Type of Employment             24.24
# Location                        0.00
# Loan Amount Request (USD)       0.00
# Current Loan Expenses (USD)     0.57
# Expense Type 1                  0.00
# Expense Type 2                  0.00
# Dependents                      8.31
# Credit Score                    5.67
# No. of Defaults                 0.00
# Has Active Credit Card          5.23
# Property ID                     0.00
# Property Age                   16.17
# Property Type                   0.00
# Property Location               1.19
# Co-Applicant                    0.00
# Property Price                  0.00
# Loan Sanction Amount (USD)      1.13
# dtype: float64

# %%
mode_employment = df1['Type of Employment'].mode()[0]
df1['Type of Employment'] = df1['Type of Employment'].fillna(mode_employment)
df1.isnull().sum()
# Out:
# C:\Users\sudhe\AppData\Local\Temp\ipykernel_19552\827257606.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Type of Employment'] = df1['Type of Employment'].fillna(mode_employment)
# Customer ID                       0
# Name                              0
# Gender                            0
# Age                               0
# Income (USD)                      0
# Income Stability               1679
# Profession                        0
# Type of Employment                0
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)     172
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                     2488
# ...

# %%
# from sklearn.impute import KNNImputer
# df_cp=df

# # Define the features for KNN
# features = ['Age', 'Income (USD)', 'Credit Score', 'Current Loan Expenses (USD)', 'Property Age', 'Loan Sanction Amount (USD)']

# # Create KNNImputer object
# knn_imputer = KNNImputer(n_neighbors=5)

# # Fit and transform the features
# df_cp[features] = knn_imputer.fit_transform(df_cp[features])

# # Impute the categorical column using mode
# mode_employment = df_cp['Type of Employment'].mode()[0]
# df_cp['Type of Employment'] = df_cp['Type of Employment'].fillna(mode_employment)
# df_cp.isnull().sum()
# Out:
# Customer ID                       0
# Name                              0
# Gender                           53
# Age                               0
# Income (USD)                      0
# Income Stability               1683
# Profession                        0
# Type of Employment                0
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)       0
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                     2493
# Credit Score                      0
# No. of Defaults                   0
# Has Active Credit Card         1566
# Property ID                       0
# Property Age                      0
# Property Type                     0
# Property Location               356
# Co-Applicant                      0
# Property Price                    0
# Loan Sanction Amount (USD)        0
# dtype: int64

# %%
df1['Income Stability'] = df1['Income Stability'].fillna(df1['Income Stability'].mode())
# Out:
# C:\Users\sudhe\AppData\Local\Temp\ipykernel_19552\3458004847.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Income Stability'] = df1['Income Stability'].fillna(df1['Income Stability'].mode())

# %%
df1['Current Loan Expenses (USD)'] = df1['Current Loan Expenses (USD)'].fillna(df1['Current Loan Expenses (USD)'].median())
# Out:
# C:\Users\sudhe\AppData\Local\Temp\ipykernel_19552\2913060080.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Current Loan Expenses (USD)'] = df1['Current Loan Expenses (USD)'].fillna(df1['Current Loan Expenses (USD)'].median())

# %%
df1['Dependents'] = df1['Dependents'].fillna(df1['Dependents'].mean())
# Out:
# C:\Users\sudhe\AppData\Local\Temp\ipykernel_19552\395454218.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Dependents'] = df1['Dependents'].fillna(df1['Dependents'].mean())

# %%
df1['Credit Score'] = df1['Credit Score'].fillna(df1['Credit Score'].mean())
# Out:
# C:\Users\sudhe\AppData\Local\Temp\ipykernel_19552\2730193041.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Credit Score'] = df1['Credit Score'].fillna(df1['Credit Score'].mean())

# %%
mode_credit_card = df1['Has Active Credit Card'].mode()[0]
df1['Has Active Credit Card'] = df1['Has Active Credit Card'].fillna(mode_credit_card)
# Out:
# C:\Users\sudhe\AppData\Local\Temp\ipykernel_19552\3754762756.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Has Active Credit Card'] = df1['Has Active Credit Card'].fillna(mode_credit_card)

# %%
df1['Property Age'] = df1['Property Age'].fillna(df1['Property Age'].median())
# Out:
# C:\Users\sudhe\AppData\Local\Temp\ipykernel_19552\4048752252.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Property Age'] = df1['Property Age'].fillna(df1['Property Age'].median())

# %%
mode_property_location = df1['Property Location'].mode()[0]
df1['Property Location'] = df1['Property Location'].fillna(mode_property_location)
# Out:
# C:\Users\sudhe\AppData\Local\Temp\ipykernel_19552\2182144961.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Property Location'] = df1['Property Location'].fillna(mode_property_location)

# %%
# df1['Loan Sanction Amount (USD)'] = df1['Loan Sanction Amount (USD)'].fillna(df1['Loan Sanction Amount (USD)'].median())

print(df1.isnull().sum())
# Out:
# Customer ID                       0
# Name                              0
# Gender                            0
# Age                               0
# Income (USD)                      0
# Income Stability               1679
# Profession                        0
# Type of Employment                0
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)       0
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                        0
# Credit Score                      0
# No. of Defaults                   0
# Has Active Credit Card            0
# Property ID                       0
# Property Age                      0
# Property Type                     0
# Property Location                 0
# Co-Applicant                      0
# Property Price                    0
# Loan Sanction Amount (USD)      339
# dtype: int64

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import OrdinalEncoder


df2=df1
columns_for_knn = ['Credit Score', 'Income Stability']

categorical_cols = df2[columns_for_knn].select_dtypes(include=['object']).columns

encoder = OrdinalEncoder()
df2[categorical_cols] = encoder.fit_transform(df2[categorical_cols])

df_knn = df2[columns_for_knn]

imputer = KNNImputer(n_neighbors=5)
df_knn_imputed = pd.DataFrame(imputer.fit_transform(df_knn), columns=columns_for_knn)

df2[categorical_cols] = encoder.inverse_transform(df2[categorical_cols])

df2.update(df_knn_imputed)
# Out:
# C:\Users\sudhe\AppData\Local\Temp\ipykernel_19552\1482943691.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[categorical_cols] = encoder.fit_transform(df2[categorical_cols])
# C:\Users\sudhe\AppData\Local\Temp\ipykernel_19552\1482943691.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[categorical_cols] = encoder.inverse_transform(df2[categorical_cols])

# %%
df2.isnull().sum()
df3=df2.dropna(subset=["Income Stability"])
df3.isnull().sum()
# Out:
# Customer ID                      0
# Name                             0
# Gender                           0
# Age                              0
# Income (USD)                     0
# Income Stability                 0
# Profession                       0
# Type of Employment               0
# Location                         0
# Loan Amount Request (USD)        0
# Current Loan Expenses (USD)      0
# Expense Type 1                   0
# Expense Type 2                   0
# Dependents                       0
# Credit Score                     0
# No. of Defaults                  0
# Has Active Credit Card           0
# Property ID                      0
# Property Age                     0
# Property Type                    0
# Property Location                0
# Co-Applicant                     0
# Property Price                   0
# Loan Sanction Amount (USD)     339
# dtype: int64

# %%
import pandas as pd
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

df4=df3

features_for_imputation = [
    'Age', 'Income (USD)', 'Income Stability', 'Loan Amount Request (USD)', 
    'Current Loan Expenses (USD)', 'Credit Score', 'No. of Defaults', 
    'Has Active Credit Card', 'Property Price'
]

df_impute = df4[features_for_imputation + ['Loan Sanction Amount (USD)']]

categorical_cols = ['Income Stability', 'Has Active Credit Card']
le = LabelEncoder()
for col in categorical_cols:
    df_impute[col] = le.fit_transform(df_impute[col].astype(str))

imputer = IterativeImputer(random_state=42)
df_imputed = pd.DataFrame(imputer.fit_transform(df_impute), columns=df_impute.columns)

df4['Loan Sanction Amount (USD)'] = df_imputed['Loan Sanction Amount (USD)']
# Out:
# C:\Users\sudhe\AppData\Local\Temp\ipykernel_19552\1699688835.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_impute[col] = le.fit_transform(df_impute[col].astype(str))
# C:\Users\sudhe\AppData\Local\Temp\ipykernel_19552\1699688835.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_impute[col] = le.fit_transform(df_impute[col].astype(str))
# C:\Users\sudhe\AppData\Local\Temp\ipykernel_19552\1699688835.py:25: SettingWithCopyWarning:
# ...

# %%
df4.isnull().sum()
# Out:
# Customer ID                     0
# Name                            0
# Gender                          0
# Age                             0
# Income (USD)                    0
# Income Stability                0
# Profession                      0
# Type of Employment              0
# Location                        0
# Loan Amount Request (USD)       0
# Current Loan Expenses (USD)     0
# Expense Type 1                  0
# Expense Type 2                  0
# Dependents                      0
# Credit Score                    0
# No. of Defaults                 0
# Has Active Credit Card          0
# Property ID                     0
# Property Age                    0
# Property Type                   0
# Property Location               0
# Co-Applicant                    0
# Property Price                  0
# Loan Sanction Amount (USD)     53
# dtype: int64

# %%
df5=df4.dropna(subset=["Loan Sanction Amount (USD)"])
df5["Has Active Credit Card"]=df5["Has Active Credit Card"].fillna(value=df5["Has Active Credit Card"].mode())
df5.isnull().sum()
# Out:
# C:\Users\sudhe\AppData\Local\Temp\ipykernel_19552\1837537221.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5["Has Active Credit Card"]=df5["Has Active Credit Card"].fillna(value=df5["Has Active Credit Card"].mode())
# Customer ID                    0
# Name                           0
# Gender                         0
# Age                            0
# Income (USD)                   0
# Income Stability               0
# Profession                     0
# Type of Employment             0
# Location                       0
# Loan Amount Request (USD)      0
# Current Loan Expenses (USD)    0
# Expense Type 1                 0
# Expense Type 2                 0
# Dependents                     0
# ...

# %%
mode_property_location1 = df1['Has Active Credit Card'].mode()[0]
df5['Has Active Credit Card'] = df1['Property Location'].fillna(mode_property_location1)
df5.isnull().sum()
# Out:
# C:\Users\sudhe\AppData\Local\Temp\ipykernel_19552\2647517336.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['Has Active Credit Card'] = df1['Property Location'].fillna(mode_property_location1)
# Customer ID                    0
# Name                           0
# Gender                         0
# Age                            0
# Income (USD)                   0
# Income Stability               0
# Profession                     0
# Type of Employment             0
# Location                       0
# Loan Amount Request (USD)      0
# Current Loan Expenses (USD)    0
# Expense Type 1                 0
# Expense Type 2                 0
# Dependents                     0
# Credit Score                   0
# ...

# %%
print(df5.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29893 entries, 0 to 29945
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Customer ID                  29893 non-null  object
#  1   Name                         29893 non-null  object
#  2   Gender                       29893 non-null  object
#  3   Age                          29893 non-null  int64
#  4   Income (USD)                 29893 non-null  float64
#  5   Income Stability             29893 non-null  object
#  6   Profession                   29893 non-null  object
#  7   Type of Employment           29893 non-null  object
#  8   Location                     29893 non-null  object
#  9   Loan Amount Request (USD)    29893 non-null  float64
#  10  Current Loan Expenses (USD)  29893 non-null  float64
#  11  Expense Type 1               29893 non-null  object
#  12  Expense Type 2               29893 non-null  object
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

relevant_columns = [
    'Age', 'Income (USD)', 'Income Stability', 'Loan Amount Request (USD)', 
    'Current Loan Expenses (USD)', 'Dependents', 'Credit Score', 
    'No. of Defaults', 'Property Age', 'Property Price', 'Loan Sanction Amount (USD)'
]

outlier_counts = {}

for col in relevant_columns:
    Q1 = df5[col].quantile(0.25)
    Q3 = df5[col].quantile(0.75)
    IQR = Q3 - Q1
    outliers = df5[(df5[col] < (Q1 - 1.5 * IQR)) | (df5[col] > (Q3 + 1.5 * IQR))]
    outlier_counts[col] = outliers.shape[0]

plt.figure(figsize=(15, 10))
sns.boxplot(data=df5[relevant_columns])
plt.xticks(rotation=45)
plt.title('Box Plot for Relevant Fields')

for col, count in outlier_counts.items():
    print(f'Number of outliers in {col}: {count}')

plt.show()
# Out:
# Number of outliers in Age: 0
# Number of outliers in Income (USD): 1869
# Number of outliers in Income Stability: 3057
# Number of outliers in Loan Amount Request (USD): 749
# Number of outliers in Current Loan Expenses (USD): 872
# Number of outliers in Dependents: 429
# Number of outliers in Credit Score: 0
# Number of outliers in No. of Defaults: 5794
# Number of outliers in Property Age: 1919
# Number of outliers in Property Price: 862
# Number of outliers in Loan Sanction Amount (USD): 441

# %%
relevant_columns = [
    'Age', 'Income (USD)', 'Income Stability', 'Loan Amount Request (USD)', 
    'Current Loan Expenses (USD)', 'Dependents', 'Credit Score', 
    'No. of Defaults', 'Property Age', 'Property Price', 'Loan Sanction Amount (USD)'
]
def remove_outliers(df, columns):
    for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        df = df[~((df[col] < (Q1 - 1.5 * IQR)) | (df[col] > (Q3 + 1.5 * IQR)))]
    return df

df5_cleaned = remove_outliers(df5, relevant_columns)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

relevant_columns = [
    'Age', 'Income (USD)', 'Income Stability', 'Loan Amount Request (USD)', 
    'Current Loan Expenses (USD)', 'Dependents', 'Credit Score', 
    'No. of Defaults', 'Property Age', 'Property Price', 'Loan Sanction Amount (USD)'
]

outlier_counts = {}

for col in relevant_columns:
    Q1 = df5_cleaned[col].quantile(0.25)
    Q3 = df5_cleaned[col].quantile(0.75)
    IQR = Q3 - Q1
    outliers = df5_cleaned[(df5_cleaned[col] < (Q1 - 1.5 * IQR)) | (df5_cleaned[col] > (Q3 + 1.5 * IQR))]
    outlier_counts[col] = outliers.shape[0]

plt.figure(figsize=(15, 10))
sns.boxplot(data=df5_cleaned[relevant_columns])
plt.xticks(rotation=45)
plt.title('Box Plot for Relevant Fields')

for col, count in outlier_counts.items():
    print(f'Number of outliers in {col}: {count}')

plt.show()
# Out:
# Number of outliers in Age: 0
# Number of outliers in Income (USD): 277
# Number of outliers in Income Stability: 0
# Number of outliers in Loan Amount Request (USD): 117
# Number of outliers in Current Loan Expenses (USD): 108
# Number of outliers in Dependents: 0
# Number of outliers in Credit Score: 0
# Number of outliers in No. of Defaults: 0
# Number of outliers in Property Age: 323
# Number of outliers in Property Price: 96
# Number of outliers in Loan Sanction Amount (USD): 53

# %%
duplicates=df5_cleaned.duplicated()
duplicate_rows=df5_cleaned[duplicates]
print(duplicate_rows)
print(duplicates.sum())
# Out:
# Empty DataFrame
# Columns: [Customer ID, Name, Gender, Age, Income (USD), Income Stability, Profession, Type of Employment, Location, Loan Amount Request (USD), Current Loan Expenses (USD), Expense Type 1, Expense Type 2, Dependents, Credit Score, No. of Defaults, Has Active Credit Card, Property ID, Property Age, Property Type, Property Location, Co-Applicant, Property Price, Loan Sanction Amount (USD)]
# Index: []
#
# [0 rows x 24 columns]
# 0

# %%
df5_cleaned.to_csv("loan.csv",index=False)
