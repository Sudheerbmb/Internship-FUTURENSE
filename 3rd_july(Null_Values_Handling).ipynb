# %% [markdown]
# <a href="https://colab.research.google.com/github/Sudheerbmb/IT/blob/main/3rd_july(Null_Values_Handling).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello")
# Out:
# Hello

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("weather_data.csv",parse_dates=["day"])
df.set_index("day",inplace=True)
print(df)
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.fillna(0)
print(df)
print(new_df)
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          0.0        9.0   Sunny
# 2017-01-05         28.0        0.0    Snow
# 2017-01-06          0.0        7.0       0
# 2017-01-07         32.0        0.0    Rain
# 2017-01-08          0.0        0.0   Sunny
# 2017-01-09          0.0        0.0       0
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.fillna({'temperature':0,'windspeed':0,'event':'no event'})
print(new_df)
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01         32.0        6.0      Rain
# 2017-01-04          0.0        9.0     Sunny
# 2017-01-05         28.0        0.0      Snow
# 2017-01-06          0.0        7.0  no event
# 2017-01-07         32.0        0.0      Rain
# 2017-01-08          0.0        0.0     Sunny
# 2017-01-09          0.0        0.0  no event
# 2017-01-10         34.0        8.0    Cloudy
# 2017-01-11         40.0       12.0     Sunny

# %%
new_Df=df.fillna(method='ffill')
print(new_Df)
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         32.0        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         28.0        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         32.0        7.0   Sunny
# 2017-01-09         32.0        7.0   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.fillna(method="bfill")
print(new_df)
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         28.0        9.0   Sunny
# 2017-01-05         28.0        7.0    Snow
# 2017-01-06         32.0        7.0    Rain
# 2017-01-07         32.0        8.0    Rain
# 2017-01-08         34.0        8.0   Sunny
# 2017-01-09         34.0        8.0  Cloudy
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.fillna(method="ffill",axis="columns")
print(new_df)
# Out:
#            temperature windspeed   event
# day
# 2017-01-01        32.0       6.0    Rain
# 2017-01-04         NaN       9.0   Sunny
# 2017-01-05        28.0      28.0    Snow
# 2017-01-06         NaN       7.0     7.0
# 2017-01-07        32.0      32.0    Rain
# 2017-01-08         NaN       NaN   Sunny
# 2017-01-09         NaN       NaN     NaN
# 2017-01-10        34.0       8.0  Cloudy
# 2017-01-11        40.0      12.0   Sunny

# %%
new_Df=df.fillna(method="bfill",limit=1)
print(new_Df)
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         28.0        9.0   Sunny
# 2017-01-05         28.0        7.0    Snow
# 2017-01-06         32.0        7.0    Rain
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09         34.0        8.0  Cloudy
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.interpolate(method='time')
print(new_df)
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    29.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
new_df=df.dropna()
print(new_df)
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.dropna(how="all")
print(new_df)
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.dropna(thresh=1)
print(new_df)
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
dt=pd.date_range("01-01-2017","11-01-2017")
idx=pd.DatetimeIndex(dt)
df=df.reindex(idx)
print(df)
# Out:
#             temperature  windspeed  event
# 2017-01-01         32.0        6.0   Rain
# 2017-01-02          NaN        NaN    NaN
# 2017-01-03          NaN        NaN    NaN
# 2017-01-04          NaN        9.0  Sunny
# 2017-01-05         28.0        NaN   Snow
# ...                 ...        ...    ...
# 2017-10-28          NaN        NaN    NaN
# 2017-10-29          NaN        NaN    NaN
# 2017-10-30          NaN        NaN    NaN
# 2017-10-31          NaN        NaN    NaN
# 2017-11-01          NaN        NaN    NaN
#
# [305 rows x 3 columns]

# %%
# Out:
#   File "<ipython-input-3-098869d2fb66>", line 2
#     df=pd.read_csv("C:\Users\sudhe\Downloads\Loan 1.csv")
#                                                         ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd
df = pd.read_csv("Loan 1.csv")

# %%
df.head()
# Out:
#   Customer ID              Name Gender  Age  Income (USD) Income Stability  \
# 0     C-26247  Tandra Olszewski      F   47       3472.69              Low
# 1     C-35067     Jeannette Cha      F   57       1184.84              Low
# 2     C-34590      Keva Godfrey      F   52       1266.27              Low
# 3     C-16668      Elva Sackett      M   65       1369.72             High
# 4     C-12196    Sade Constable      F   60       1939.23             High
#
#              Profession Type of Employment    Location  \
# 0  Commercial associate           Managers  Semi-Urban
# 1               Working        Sales staff       Rural
# 2               Working                NaN  Semi-Urban
# 3             Pensioner                NaN       Rural
# 4             Pensioner                NaN       Urban
#
#    Loan Amount Request (USD)  ...  Dependents Credit Score No. of Defaults  \
# 0                  137088.98  ...         2.0       799.14               0
# ...

# %%
df.isnull()
# Out:
#        Customer ID   Name  Gender    Age  Income (USD)  Income Stability  \
# 0            False  False   False  False         False             False
# 1            False  False   False  False         False             False
# 2            False  False   False  False         False             False
# 3            False  False   False  False         False             False
# 4            False  False   False  False         False             False
# ...            ...    ...     ...    ...           ...               ...
# 19995        False  False   False  False         False             False
# 19996        False  False   False  False         False             False
# 19997        False  False   False  False         False             False
# 19998        False  False   False  False         False             False
# 19999        False  False   False  False         False             False
#
#        Profession  Type of Employment  Location  Loan Amount Request (USD)  \
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID                       0
# Name                              0
# Gender                           31
# Age                               0
# Income (USD)                    750
# Income Stability                813
# Profession                        0
# Type of Employment             4689
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)      83
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                     1142
# Credit Score                    743
# No. of Defaults                   0
# Has Active Credit Card         1076
# Property ID                       0
# Property Age                    892
# Property Type                     0
# Property Location               160
# Co-Applicant                      0
# Property Price                    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Customer ID                  20000 non-null  object
#  1   Name                         20000 non-null  object
#  2   Gender                       19969 non-null  object
#  3   Age                          20000 non-null  int64
#  4   Income (USD)                 19250 non-null  float64
#  5   Income Stability             19187 non-null  object
#  6   Profession                   20000 non-null  object
#  7   Type of Employment           15311 non-null  object
#  8   Location                     20000 non-null  object
#  9   Loan Amount Request (USD)    20000 non-null  float64
#  10  Current Loan Expenses (USD)  19917 non-null  float64
#  11  Expense Type 1               20000 non-null  object
#  12  Expense Type 2               20000 non-null  object
# ...

# %%
df2=df.fillna(0)
# print(df2)
df2.isnull().sum()
# Out:
# Customer ID                    0
# Name                           0
# Gender                         0
# Age                            0
# Income (USD)                   0
# Income Stability               0
# Profession                     0
# Type of Employment             0
# Location                       0
# Loan Amount Request (USD)      0
# Current Loan Expenses (USD)    0
# Expense Type 1                 0
# Expense Type 2                 0
# Dependents                     0
# Credit Score                   0
# No. of Defaults                0
# Has Active Credit Card         0
# Property ID                    0
# Property Age                   0
# Property Type                  0
# Property Location              0
# Co-Applicant                   0
# Property Price                 0
# dtype: int64

# %%
df3=df.fillna(method="ffill")
print(df3)
# Out:
#       Customer ID              Name Gender  Age  Income (USD)  \
# 0         C-26247  Tandra Olszewski      F   47       3472.69
# 1         C-35067     Jeannette Cha      F   57       1184.84
# 2         C-34590      Keva Godfrey      F   52       1266.27
# 3         C-16668      Elva Sackett      M   65       1369.72
# 4         C-12196    Sade Constable      F   60       1939.23
# ...           ...               ...    ...  ...           ...
# 19995      C-9076    Tobias Davilla      F   19       1349.60
# 19996     C-17587    Evelina Hodges      M   22       2019.78
# 19997     C-46479   Karlyn Mckinzie      M   19       2252.03
# 19998      C-3099    Mariana Pulver      F   21       1845.35
# 19999     C-43482   Mechelle Boddie      M   21       5233.16
#
#       Income Stability            Profession Type of Employment    Location  \
# 0                  Low  Commercial associate           Managers  Semi-Urban
# ...

# %%
df5=df.fillna(method="ffill",axis=1)

# %%
df6 = df.fillna({'Type of Employment': 'Yet to ask', 'Dependents': '2.5'})
df6

# %%
df7 = df.fillna(value=df['Dependents'].mean())
df7
# Out:
#       Customer ID              Name Gender  Age  Income (USD)  \
# 0         C-26247  Tandra Olszewski      F   47       3472.69
# 1         C-35067     Jeannette Cha      F   57       1184.84
# 2         C-34590      Keva Godfrey      F   52       1266.27
# 3         C-16668      Elva Sackett      M   65       1369.72
# 4         C-12196    Sade Constable      F   60       1939.23
# ...           ...               ...    ...  ...           ...
# 19995      C-9076    Tobias Davilla      F   19       1349.60
# 19996     C-17587    Evelina Hodges      M   22       2019.78
# 19997     C-46479   Karlyn Mckinzie      M   19       2252.03
# 19998      C-3099    Mariana Pulver      F   21       1845.35
# 19999     C-43482   Mechelle Boddie      M   21       5233.16
#
#       Income Stability            Profession Type of Employment    Location  \
# 0                  Low  Commercial associate           Managers  Semi-Urban
# ...

# %%
df8 = df['Dependents'].fillna(value=df['Dependents'].median())
df8
# Out:
# 0        2.0
# 1        2.0
# 2        3.0
# 3        2.0
# 4        2.0
#         ...
# 19995    4.0
# 19996    2.0
# 19997    1.0
# 19998    2.0
# 19999    3.0
# Name: Dependents, Length: 20000, dtype: float64

# %%
df9 = df['Dependents'].fillna(value=df['Dependents'].max())
df9
# Out:
# 0         2.0
# 1         2.0
# 2         3.0
# 3         2.0
# 4        13.0
#          ...
# 19995     4.0
# 19996    13.0
# 19997     1.0
# 19998     2.0
# 19999     3.0
# Name: Dependents, Length: 20000, dtype: float64

# %%
df10 = df.dropna()
df10
# Out:
#       Customer ID              Name Gender  Age  Income (USD)  \
# 0         C-26247  Tandra Olszewski      F   47       3472.69
# 1         C-35067     Jeannette Cha      F   57       1184.84
# 5          C-2600         Gina Weir      F   59       2944.81
# 6          C-9047    Lacey Cybulski      M   43       1957.31
# 11        C-43027       Karlyn Cree      M   29       2183.59
# ...           ...               ...    ...  ...           ...
# 19992     C-27000  Jackson Wheeless      M   18       2373.38
# 19993     C-39756    Alethia Dively      M   25       2061.80
# 19994     C-32138       Cuc Verrett      M   19       3262.08
# 19997     C-46479   Karlyn Mckinzie      M   19       2252.03
# 19999     C-43482   Mechelle Boddie      M   21       5233.16
#
#       Income Stability            Profession Type of Employment    Location  \
# 0                  Low  Commercial associate           Managers  Semi-Urban
# ...

# %%
df11 =df.dropna(how='any')
df11
# Out:
#       Customer ID              Name Gender  Age  Income (USD)  \
# 0         C-26247  Tandra Olszewski      F   47       3472.69
# 1         C-35067     Jeannette Cha      F   57       1184.84
# 5          C-2600         Gina Weir      F   59       2944.81
# 6          C-9047    Lacey Cybulski      M   43       1957.31
# 11        C-43027       Karlyn Cree      M   29       2183.59
# ...           ...               ...    ...  ...           ...
# 19992     C-27000  Jackson Wheeless      M   18       2373.38
# 19993     C-39756    Alethia Dively      M   25       2061.80
# 19994     C-32138       Cuc Verrett      M   19       3262.08
# 19997     C-46479   Karlyn Mckinzie      M   19       2252.03
# 19999     C-43482   Mechelle Boddie      M   21       5233.16
#
#       Income Stability            Profession Type of Employment    Location  \
# 0                  Low  Commercial associate           Managers  Semi-Urban
# ...

# %%
df12 = df.dropna(how='all')
df12
# Out:
#       Customer ID              Name Gender  Age  Income (USD)  \
# 0         C-26247  Tandra Olszewski      F   47       3472.69
# 1         C-35067     Jeannette Cha      F   57       1184.84
# 2         C-34590      Keva Godfrey      F   52       1266.27
# 3         C-16668      Elva Sackett      M   65       1369.72
# 4         C-12196    Sade Constable      F   60       1939.23
# ...           ...               ...    ...  ...           ...
# 19995      C-9076    Tobias Davilla      F   19       1349.60
# 19996     C-17587    Evelina Hodges      M   22       2019.78
# 19997     C-46479   Karlyn Mckinzie      M   19       2252.03
# 19998      C-3099    Mariana Pulver      F   21       1845.35
# 19999     C-43482   Mechelle Boddie      M   21       5233.16
#
#       Income Stability            Profession Type of Employment    Location  \
# 0                  Low  Commercial associate           Managers  Semi-Urban
# ...

# %%
df13 = df.dropna(axis=1)
df13
#IMP IMP
# Out:
#       Customer ID              Name  Age            Profession    Location  \
# 0         C-26247  Tandra Olszewski   47  Commercial associate  Semi-Urban
# 1         C-35067     Jeannette Cha   57               Working       Rural
# 2         C-34590      Keva Godfrey   52               Working  Semi-Urban
# 3         C-16668      Elva Sackett   65             Pensioner       Rural
# 4         C-12196    Sade Constable   60             Pensioner       Urban
# ...           ...               ...  ...                   ...         ...
# 19995      C-9076    Tobias Davilla   19  Commercial associate  Semi-Urban
# 19996     C-17587    Evelina Hodges   22               Working       Urban
# 19997     C-46479   Karlyn Mckinzie   19               Working  Semi-Urban
# 19998      C-3099    Mariana Pulver   21               Working  Semi-Urban
# 19999     C-43482   Mechelle Boddie   21               Working  Semi-Urban
#
#        Loan Amount Request (USD) Expense Type 1 Expense Type 2  \
# ...

# %%
df14 = df.dropna(subset=['Type of Employment', 'Dependents'])
df14
# Out:
#       Customer ID              Name Gender  Age  Income (USD)  \
# 0         C-26247  Tandra Olszewski      F   47       3472.69
# 1         C-35067     Jeannette Cha      F   57       1184.84
# 5          C-2600         Gina Weir      F   59       2944.81
# 6          C-9047    Lacey Cybulski      M   43       1957.31
# 9         C-11606     Hellen Alexis      F   27        949.17
# ...           ...               ...    ...  ...           ...
# 19992     C-27000  Jackson Wheeless      M   18       2373.38
# 19993     C-39756    Alethia Dively      M   25       2061.80
# 19994     C-32138       Cuc Verrett      M   19       3262.08
# 19997     C-46479   Karlyn Mckinzie      M   19       2252.03
# 19999     C-43482   Mechelle Boddie      M   21       5233.16
#
#       Income Stability            Profession Type of Employment    Location  \
# 0                  Low  Commercial associate           Managers  Semi-Urban
# ...

# %%
df15 =  df.dropna(thresh=5)
df15
# Out:
#       Customer ID              Name Gender  Age  Income (USD)  \
# 0         C-26247  Tandra Olszewski      F   47       3472.69
# 1         C-35067     Jeannette Cha      F   57       1184.84
# 2         C-34590      Keva Godfrey      F   52       1266.27
# 3         C-16668      Elva Sackett      M   65       1369.72
# 4         C-12196    Sade Constable      F   60       1939.23
# ...           ...               ...    ...  ...           ...
# 19995      C-9076    Tobias Davilla      F   19       1349.60
# 19996     C-17587    Evelina Hodges      M   22       2019.78
# 19997     C-46479   Karlyn Mckinzie      M   19       2252.03
# 19998      C-3099    Mariana Pulver      F   21       1845.35
# 19999     C-43482   Mechelle Boddie      M   21       5233.16
#
#       Income Stability            Profession Type of Employment    Location  \
# 0                  Low  Commercial associate           Managers  Semi-Urban
# ...

# %%
df16 = df.interpolate(method='linear')
df16
# Out:
#       Customer ID              Name Gender  Age  Income (USD)  \
# 0         C-26247  Tandra Olszewski      F   47       3472.69
# 1         C-35067     Jeannette Cha      F   57       1184.84
# 2         C-34590      Keva Godfrey      F   52       1266.27
# 3         C-16668      Elva Sackett      M   65       1369.72
# 4         C-12196    Sade Constable      F   60       1939.23
# ...           ...               ...    ...  ...           ...
# 19995      C-9076    Tobias Davilla      F   19       1349.60
# 19996     C-17587    Evelina Hodges      M   22       2019.78
# 19997     C-46479   Karlyn Mckinzie      M   19       2252.03
# 19998      C-3099    Mariana Pulver      F   21       1845.35
# 19999     C-43482   Mechelle Boddie      M   21       5233.16
#
#       Income Stability            Profession Type of Employment    Location  \
# 0                  Low  Commercial associate           Managers  Semi-Urban
# ...

# %%
df17 = df.interpolate(method='polynomial', order=2)
df17
# Out:
#       Customer ID              Name Gender  Age  Income (USD)  \
# 0         C-26247  Tandra Olszewski      F   47       3472.69
# 1         C-35067     Jeannette Cha      F   57       1184.84
# 2         C-34590      Keva Godfrey      F   52       1266.27
# 3         C-16668      Elva Sackett      M   65       1369.72
# 4         C-12196    Sade Constable      F   60       1939.23
# ...           ...               ...    ...  ...           ...
# 19995      C-9076    Tobias Davilla      F   19       1349.60
# 19996     C-17587    Evelina Hodges      M   22       2019.78
# 19997     C-46479   Karlyn Mckinzie      M   19       2252.03
# 19998      C-3099    Mariana Pulver      F   21       1845.35
# 19999     C-43482   Mechelle Boddie      M   21       5233.16
#
#       Income Stability            Profession Type of Employment    Location  \
# 0                  Low  Commercial associate           Managers  Semi-Urban
# ...

# %%
df19 = df.interpolate(method='pad')
df19
# Out:
#       Customer ID              Name Gender  Age  Income (USD)  \
# 0         C-26247  Tandra Olszewski      F   47       3472.69
# 1         C-35067     Jeannette Cha      F   57       1184.84
# 2         C-34590      Keva Godfrey      F   52       1266.27
# 3         C-16668      Elva Sackett      M   65       1369.72
# 4         C-12196    Sade Constable      F   60       1939.23
# ...           ...               ...    ...  ...           ...
# 19995      C-9076    Tobias Davilla      F   19       1349.60
# 19996     C-17587    Evelina Hodges      M   22       2019.78
# 19997     C-46479   Karlyn Mckinzie      M   19       2252.03
# 19998      C-3099    Mariana Pulver      F   21       1845.35
# 19999     C-43482   Mechelle Boddie      M   21       5233.16
#
#       Income Stability            Profession Type of Employment    Location  \
# 0                  Low  Commercial associate           Managers  Semi-Urban
# ...

# %%
import numpy as np
df20 = df.replace(to_replace= np.nan, value= 0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
q1 = df['Age'].quantile(0.25)  # First quartile (25th percentile)
q2 = df['Age'].quantile(0.5)   # Second quartile (median)
q3 = df['Age'].quantile(0.75)  # Third quartile (75th percentile)

print("First Quartile (Q1):", q1)
print("Median (Q2):", q2)
print("Third Quartile (Q3):", q3)

# Create a box plot to visualize skewness
sns.boxplot(x=df['Age'])
plt.title('Box Plot for Age')
plt.show()
# Out:
# First Quartile (Q1): 25.0
# Median (Q2): 40.0
# Third Quartile (Q3): 55.0

# %%
q1 = df['Age'].quantile(0.25)
q3 = df['Age'].quantile(0.75)
iqr = q3 - q1  # Interquartile Range

# lower and upper whiskers
lower_whisker = q1 - 1.5 * iqr
upper_whisker = q3 + 1.5 * iqr

print("Lower Whisker:", lower_whisker)
print("Upper Whisker:", upper_whisker)
# Out:
# Lower Whisker: -20.0
# Upper Whisker: 100.0

# %%
df_lower_filled = df.fillna(lower_whisker)  # Fill with lower whisker
df_upper_filled = df.fillna(upper_whisker)  # Fill with upper whisker

# Display the results
print("Original DataFrame:")
df
# Out:
# Original DataFrame:
#       Customer ID              Name Gender  Age  Income (USD)  \
# 0         C-26247  Tandra Olszewski      F   47       3472.69
# 1         C-35067     Jeannette Cha      F   57       1184.84
# 2         C-34590      Keva Godfrey      F   52       1266.27
# 3         C-16668      Elva Sackett      M   65       1369.72
# 4         C-12196    Sade Constable      F   60       1939.23
# ...           ...               ...    ...  ...           ...
# 19995      C-9076    Tobias Davilla      F   19       1349.60
# 19996     C-17587    Evelina Hodges      M   22       2019.78
# 19997     C-46479   Karlyn Mckinzie      M   19       2252.03
# 19998      C-3099    Mariana Pulver      F   21       1845.35
# 19999     C-43482   Mechelle Boddie      M   21       5233.16
#
#       Income Stability            Profession Type of Employment    Location  \
# 0                  Low  Commercial associate           Managers  Semi-Urban
# ...

# %%
# Assuming df is your loan dataset loaded properly

# Select columns for KNN imputation
columns_for_knn = ['Income (USD)', 'Credit Score', 'Property Age']

# Visualize histograms before imputation
plt.figure(figsize=(14, 10))
for i, col in enumerate(columns_for_knn, 1):
    plt.subplot(3, 2, i)
    plt.hist(df[col].dropna(), bins=30, color='blue', edgecolor='black')
    plt.title(f'Histogram of {col} - Before Imputation')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
from sklearn.impute import KNNImputer

# Perform KNN imputation
imputer = KNNImputer(n_neighbors=5)
df_knn_imputed = pd.DataFrame(imputer.fit_transform(df[columns_for_knn]), columns=columns_for_knn)

# Visualize histograms after imputation
plt.figure(figsize=(14, 10))
for i, col in enumerate(columns_for_knn, 1):
    plt.subplot(3, 2, i)
    plt.hist(df_knn_imputed[col], bins=30, color='green', edgecolor='black')
    plt.title(f'Histogram of {col} - After KNN Imputation')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 10))
for i, col in enumerate(columns_for_knn, 1):
    plt.subplot(3, 2, i)
    plt.hist(df[col].dropna(), bins=30, color='blue', edgecolor='black')
    plt.title(f'Histogram of {col} - Before Imputation')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.grid(True)

plt.tight_layout()
plt.show()

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# Perform MICE imputation
imputer_mice = IterativeImputer(random_state=0)
df_mice_imputed = pd.DataFrame(imputer_mice.fit_transform(df[columns_for_knn]), columns=columns_for_knn)

# Visualize histograms after imputation
plt.figure(figsize=(14, 10))
for i, col in enumerate(columns_for_knn, 1):
    plt.subplot(3, 2, i)
    plt.hist(df_mice_imputed[col], bins=30, color='orange', edgecolor='black')
    plt.title(f'Histogram of {col} - After MICE Imputation')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
q1 = df['Age'].quantile(0.25)  # First quartile (25th percentile)
q2 = df['Age'].quantile(0.5)   # Second quartile (median)
q3 = df['Age'].quantile(0.75)  # Third quartile (75th percentile)

print("First Quartile (Q1):", q1)
print("Median (Q2):", q2)
print("Third Quartile (Q3):", q3)

# Create a histogram to visualize original distribution
plt.figure(figsize=(10, 6))
plt.hist(df['Age'], bins=30, color='lightblue', edgecolor='black')
plt.axvline(x=q1, color='red', linestyle='--', label='Q1 (25th percentile)')
plt.axvline(x=q2, color='green', linestyle='--', label='Q2 (50th percentile)')
plt.axvline(x=q3, color='blue', linestyle='--', label='Q3 (75th percentile)')
plt.title('Histogram of Age - Original Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# First Quartile (Q1): 25.0
# Median (Q2): 40.0
# Third Quartile (Q3): 55.0

# %%
#AFTER
# Determine lower and upper whiskers for outlier detection
iqr = q3 - q1  # Interquartile Range
lower_whisker = q1 - 1.5 * iqr
upper_whisker = q3 + 1.5 * iqr

print("Lower Whisker:", lower_whisker)
print("Upper Whisker:", upper_whisker)

# Fill NaN values with lower and upper whiskers
df_lower_filled = df.fillna(lower_whisker)  # Fill with lower whisker
df_upper_filled = df.fillna(upper_whisker)  # Fill with upper whisker

# Create histograms to visualize the filled distributions
plt.figure(figsize=(14, 6))

# Histogram after filling with lower whisker
plt.subplot(1, 2, 1)
plt.hist(df_lower_filled['Age'], bins=30, color='orange', edgecolor='black')
plt.axvline(x=lower_whisker, color='red', linestyle='--', label='Lower Whisker')
plt.title('Histogram of Age - Filled with Lower Whisker')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)

# Histogram after filling with upper whisker
plt.subplot(1, 2, 2)
plt.hist(df_upper_filled['Age'], bins=30, color='green', edgecolor='black')
plt.axvline(x=upper_whisker, color='blue', linestyle='--', label='Upper Whisker')
plt.title('Histogram of Age - Filled with Upper Whisker')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Lower Whisker: -20.0
# Upper Whisker: 100.0
